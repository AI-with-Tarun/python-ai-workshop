# %% [markdown]
# ## Run on T4 GPU

# %%
# !pip install llama-index
# !pip install llama-index-readers-file

# %%
# !pip install llama-index-embeddings-huggingface
# !pip install llama-index-llms-google-genai

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
import os
from google.colab import userdata

os.environ['GOOGLE_API_KEY'] = userdata.get("GOOGLE_API_KEY")

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.core.node_parser import SentenceSplitter

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.google_genai import GoogleGenAI

# %%
model_name = "thenlper/gte-large"
embed_model = HuggingFaceEmbedding(model_name=model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:86: UserWarning:
# Access to the secret `HF_TOKEN` has not been granted on this notebook.
# You will not be requested again.
# Please restart the session if you want to be prompted again.
#   warnings.warn(
# modules.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
llm = GoogleGenAI(model="gemini-2.5-flash",max_tokens=4096,temperature=0.1)

# %%
from llama_index.core import Settings

Settings.embed_model = embed_model
Settings.llm = llm

# %%
documents = SimpleDirectoryReader("./data").load_data()

# %%
node_parser = SentenceSplitter(chunk_size=1000)
nodes = node_parser.get_nodes_from_documents(documents)

# %%
vector_index = VectorStoreIndex(nodes)
retriever = vector_index.as_retriever(similarity_top_k=3)

# %%
from llama_index.core.evaluation import RetrieverEvaluator
from llama_index.core.evaluation import generate_question_context_pairs

# %%
retriever_evaluator = RetrieverEvaluator.from_metric_names(
    ["mrr", "hit_rate"], retriever=retriever
)

# %%
qa_dataset = generate_question_context_pairs(
    nodes,
    llm=llm,
    num_questions_per_chunk=2
)
# Out:
# 100%|██████████| 12/12 [01:05<00:00,  5.49s/it]

# %%
dict(qa_dataset).keys()
# Out:
# dict_keys(['queries', 'corpus', 'relevant_docs', 'mode'])

# %%
qa_dataset.queries
# Out:
# {'9fa3b6cb-559a-4042-b5f0-3ab60f33473c': 'Here are two questions for your upcoming quiz/examination:',
#  '470e7ea4-c06f-4b80-a109-3cff71bb5e51': 'Describe the primary motivation for developing LuxLlama, detailing the base model it was fine-tuned from and the specific Parameter-Efficient Fine-Tuning (PEFT) technique employed, along with its optimization kernel.',
#  '8ac5537f-7c4b-4a3d-8a45-f693cfe16abe': 'Here are two questions for your upcoming quiz/examination:',
#  '76dc95b4-dcbf-40dc-a9bb-a6782c095d12': 'The text highlights that building general multilingual models is often insufficient for low-resource languages like Luxembourgish. According to the document, what specific details do these general models frequently miss, and what two contributions did the LuxLlama project aim to provide to fill this gap?',
#  '01dc0b4b-4f7d-47d4-ba7d-14376cd1ccab': 'Here are two questions for your upcoming quiz/examination:',
#  '225cad79-eee4-47e8-b041-4f61db760227': '---',
#  '46fabcc9-65ea-42c2-bb5d-4b10263202cb': 'During the training process, an effective batch size of 32 was achieved. Explain how this effective batch size was calculated, specifying the two hyperparameters involved. Additionally, describe the purpose of setting a `warmup_ratio` in the learning rate schedule.',
#  '7a4f3cdf-b224-4099-abf4-be885232e3f5': 'The Liger kernel was activated to enhance the efficiency of the fine-tuning process. Name two specific LLM operations that Liger optimizes through its Triton kernels. Furthermore, what is the primary objective of the LUXELLA benchmark, and how was its dataset generated?',
#  'f144f5c2-3be6-4bcb-88b1-1255666cc14b': 'Describe the structured methodology used for the generation of the LUXELLA dataset, detailing how prompt engineering, randomization, and iterative loops contributed to creating a diverse and comprehensive set of questions.',
#  '7d172610-807f-44be-be25-f8d43b2efa8f': 'Explain the "dual-LLM approach" employed by the LUXELLA benchmark for evaluating model responses. Discuss at least two significant advantages of this evaluation system and provide examples of insights gained from the detailed analysis of scores regarding model strengths and weaknesses across different linguistic categories and difficulty levels.',
#  '50ac4941-b590-4bc9-9748-2d4fc2dc323e': 'According to the provided text, which model achieved the highest aggregate score on the LUXELLA benchmark, and what was that score? List the scores of the four baseline models evaluated alongside it.',
#  '387bf3aa-bf4a-498b-8349-d22444682f08': "Describe the experimental setup used for evaluating LuxLlama and the baseline models on the LUXELLA benchmark, including the types of models evaluated and the scope of the benchmark's questions. What primary conclusion did the authors draw regarding the effectiveness of their targeted fine-tuning approach based on the overall performance results?",
#  'd378c701-e20e-4e96-bf85-092d20ad8b34': 'Here are two questions for your upcoming quiz/examination:',
#  '7bb0d668-ee87-43a1-8635-db0e8b642ec6': 'Based on the LUXELLA benchmark analysis, describe the general performance trends observed for language models in "receptive tasks and translation into English" compared to categories requiring "deep grammatical knowledge." Provide specific examples and scores for at least one category from each type (receptive/translation and deep grammatical knowledge) to illustrate your answer, mentioning at least three different models.',
#  '2225af84-5cfc-479a-9025-cc89e1d86955': "According to Section 6.4, describe the general trend observed in model performance as the question difficulty increased on the LUXELLA benchmark. Illustrate this trend by providing LuxLlama's specific scores for each of the four difficulty levels (beginner, intermediate, advanced, and native).",
#  '352933d2-8a19-407e-97ec-e88152c2a320': 'Based on the "Conclusion and Limitations" section, what are the two primary contributions of this work regarding LuxLlama and the LUXELLA benchmark? Additionally, identify two specific areas where persistent challenges remain, highlighting the need for continued research and development.',
#  'bab01a31-d39e-43bd-af0f-14439ff52a3e': 'Here are two questions for your upcoming quiz/examination:',
#  'c3ce15b4-ee24-42e1-ab35-f6910df4dd42': 'Based on the context provided, what does the acronym LUXELLA stand for, and what specific role did Dr. Farouk Mansouri from LuxProvide fulfill in the research project?',
#  'effa4a67-2de8-450b-bee4-ef31cdf0cb3d': 'Here are two questions for your upcoming quiz/examination:',
#  '873cb699-c594-4489-a1c5-b9408ad0aa9c': 'Based on the provided references, identify "Camembert" and list at least three of its key contributors.',
#  '874572d1-257d-49f2-93dc-ce3ad1c9c844': '**Question 1:**',
#  '0e3731e6-6022-48ff-bdb9-537596b10463': 'According to the provided text, what is a popular nature-related hobby in Luxembourg?',
#  '7e2c74fe-0726-4205-bf06-0ebf60628db6': 'Hei sinn 2 Froen fir Ären nächste Quiz/Examen, baséiert op den uewe genannten Informatiounen:',
#  'a7510abb-d8e3-4616-a452-05f797e7cc11': '**Fro 1 (Lauschterverständnes):**'}

# %%
qa_dataset.relevant_docs
# Out:
# {'9fa3b6cb-559a-4042-b5f0-3ab60f33473c': ['be3d248c-34eb-41be-8ccb-2dabc9fa54f0'],
#  '470e7ea4-c06f-4b80-a109-3cff71bb5e51': ['be3d248c-34eb-41be-8ccb-2dabc9fa54f0'],
#  '8ac5537f-7c4b-4a3d-8a45-f693cfe16abe': ['65e3f7ae-9b32-4b4c-b665-474c79a64144'],
#  '76dc95b4-dcbf-40dc-a9bb-a6782c095d12': ['65e3f7ae-9b32-4b4c-b665-474c79a64144'],
#  '01dc0b4b-4f7d-47d4-ba7d-14376cd1ccab': ['8680cc36-325e-462f-9abd-c0b8c5f86f77'],
#  '225cad79-eee4-47e8-b041-4f61db760227': ['8680cc36-325e-462f-9abd-c0b8c5f86f77'],
#  '46fabcc9-65ea-42c2-bb5d-4b10263202cb': ['4b4905a0-1de1-4990-9f15-6bd2539524e9'],
#  '7a4f3cdf-b224-4099-abf4-be885232e3f5': ['4b4905a0-1de1-4990-9f15-6bd2539524e9'],
#  'f144f5c2-3be6-4bcb-88b1-1255666cc14b': ['fe002f0d-4782-4920-84b3-9b698270ddf1'],
#  '7d172610-807f-44be-be25-f8d43b2efa8f': ['fe002f0d-4782-4920-84b3-9b698270ddf1'],
#  '50ac4941-b590-4bc9-9748-2d4fc2dc323e': ['499d67cb-7e08-4631-8048-9eb3125e750a'],
#  '387bf3aa-bf4a-498b-8349-d22444682f08': ['499d67cb-7e08-4631-8048-9eb3125e750a'],
#  'd378c701-e20e-4e96-bf85-092d20ad8b34': ['46d3f2d6-fb47-4a51-b16c-110073970fc6'],
#  '7bb0d668-ee87-43a1-8635-db0e8b642ec6': ['46d3f2d6-fb47-4a51-b16c-110073970fc6'],
#  '2225af84-5cfc-479a-9025-cc89e1d86955': ['1e2314f8-b796-419d-8938-524958c05eef'],
#  '352933d2-8a19-407e-97ec-e88152c2a320': ['1e2314f8-b796-419d-8938-524958c05eef'],
#  'bab01a31-d39e-43bd-af0f-14439ff52a3e': ['a7de0f35-29ab-4d8e-a63f-0d6ef5669404'],
#  'c3ce15b4-ee24-42e1-ab35-f6910df4dd42': ['a7de0f35-29ab-4d8e-a63f-0d6ef5669404'],
#  'effa4a67-2de8-450b-bee4-ef31cdf0cb3d': ['8f6b29ec-bde6-4a5f-bdeb-7f69f0f6573b'],
#  '873cb699-c594-4489-a1c5-b9408ad0aa9c': ['8f6b29ec-bde6-4a5f-bdeb-7f69f0f6573b'],
#  '874572d1-257d-49f2-93dc-ce3ad1c9c844': ['af4d7acd-6dff-4f86-94ec-a1e57f0c99ff'],
#  '0e3731e6-6022-48ff-bdb9-537596b10463': ['af4d7acd-6dff-4f86-94ec-a1e57f0c99ff'],
#  '7e2c74fe-0726-4205-bf06-0ebf60628db6': ['ae5270ed-c0c7-4b53-b113-c9b4d379c03e'],
#  'a7510abb-d8e3-4616-a452-05f797e7cc11': ['ae5270ed-c0c7-4b53-b113-c9b4d379c03e']}

# %%
qa_dataset.corpus

# %%
nest_asyncio.apply()
eval_results = await retriever_evaluator.aevaluate_dataset(qa_dataset)

# %%
def display_results(name, eval_results):
    import pandas as pd

    metric_dicts = []
    for eval_result in eval_results:
        metric_dict = eval_result.metric_vals_dict
        metric_dicts.append(metric_dict)

    full_df = pd.DataFrame(metric_dicts)

    hit_rate = full_df["hit_rate"].mean()
    mrr = full_df["mrr"].mean()

    metric_df = pd.DataFrame(
        {"Retriever Name": [name], "Hit Rate": [hit_rate], "MRR": [mrr]}
    )

    return metric_df

# %%
display_results(f"{model_name} Retriever", eval_results)
# Out:
#                  Retriever Name  Hit Rate       MRR
# 0  thenlper/gte-large Retriever  0.666667  0.569444
